# %% [markdown]
# Forensic Investigations with Python
# ===
#
# In February 2005, Wichita police forensic investigator Mr. Randy Stone unraveled the  nal clues of a 30-year-old mystery. A couple of days earlier, KSAS Television station had handed the police a 3.5”  floppy disk they had received from the infamous BTK (Bind, Torture, Kill) Killer. Responsible for at least 10 murders from 1974 to 1991, the BTK Killer eluded capture while repeatedly taunting the police and his victims. On February 16th, 2005, the BTK Killer sent the television station a 3.5” disk with communication instructions. Among these instructions, the disk contained a file named Test.A.rtf. (Regan, 2006). While the  file contained instructions from the BTK Killer, it also contained something else: metadata. Embedded in the Microsoft proprietary
# Rich Text Format (RTF), the  file contained the  first name of the BTK Killer and the physical location at which the user had last saved the  file.
#
# This narrowed the investigation to a man named Denis at the local Wichita Christ Lutheran Church. Mr. Stone verified that a man named Denis Rader served as a church officier at the Lutheran Church (Regan, 2006). With this information, police requested a warrant for a DNA sample from the medical records of Denis Rader’s daughter (Shapiro, 2007). The DNA sample confirmed what Mr. Stone already knew—Denis Rader was the BTK Killer. A 31-year investigation that had exhausted 100,000 man hours ended with Mr. Stone’s examination of metadata (Regan, 2006).

# %% [markdown]
# RECOVER DELETED ITEMS
# ---

# %% [markdown]
# METADATA
# ---
# Using PyPDF2 to Parse PDF Metadata
# ---
# Let’s use Python to quickly recreate the forensic investigation of a document that proved useful in the arrest of a member of the hacker group Anonymous.

# %%
# Row data information
from PyPDF2 import PdfFileReader
pdf_toread = PdfFileReader(open("../book/ch4.pdf", "rb"))
pdf_info = pdf_toread.getDocumentInfo()
print(str(pdf_info))
# Out:
# {'/Producer': 'Adobe PDF Library 9.9', '/doi': '10.1016/B978-1-59-749957-6.00004-1', '/CreationDate': "D:20121106094325+05'30'", '/ElsevierWebPDFSpecifications': '6.3', '/robots': 'noindex', '/ModDate': "D:20130605170429+05'30'", '/Title': 'Network Traffic Analysis with Python', '/Creator': 'Elsevier', '/Trapped': '/Unknown', '/Subject': 'Violent Python, First Edition (2013) 125-169. doi:10.1016/B978-1-59-749957-6.00004-1', '/Keywords': ''}

# %% [markdown]
# Not easy to read the dict-type data, use python to finalize the data:
#
# ```
# Dict Type:
#    data={key1:value1, key2:val2,...}
# -> data[key1] = value1
# ```
# Python solution:
# ```Python
#    data = (dict type ...)
#    for item in data:
#        print('[+] ' + item + ':' + data[item])
#                        ꜛ              ꜛ
#                       key           value
#  ```

# %%
import PyPDF2

from PyPDF2 import PdfFileReader


def printMeta(fileName):
    pdfFile = PdfFileReader(open(fileName, 'rb'))
    docInfo = pdfFile.getDocumentInfo()
    print('[*] PDF MetaData For: ' + str(fileName))
    for metaItem in docInfo:
        print('[+] ' + metaItem + ':' + docInfo[metaItem])


def pdfRead(fileName):
    """
    Usage:
    printRead(File)
    
    For example,
        pdfRead('../book/ch4.pdf')
    """    
    printMeta(fileName)

# %%
help(pdfRead)
# Out:
# Help on function pdfRead in module __main__:
#
# pdfRead(fileName)
#     Usage:
#     printRead(File)
#
#     For example,
#         pdfRead('../book/ch4.pdf')

# %%
#pdfRead('SeniorCitizens.pdf')
pdfRead('../book/ch4.pdf')
# Out:
# [*] PDF MetaData For: ../book/ch4.pdf
# [+] /ModDate:D:20130605170429+05'30'
# [+] /ElsevierWebPDFSpecifications:6.3
# [+] /Trapped:/Unknown
# [+] /robots:noindex
# [+] /Creator:Elsevier
# [+] /Subject:Violent Python, First Edition (2013) 125-169. doi:10.1016/B978-1-59-749957-6.00004-1
# [+] /Title:Network Traffic Analysis with Python
# [+] /Keywords:
# [+] /CreationDate:D:20121106094325+05'30'
# [+] /doi:10.1016/B978-1-59-749957-6.00004-1
# [+] /Producer:Adobe PDF Library 9.9

# %% [markdown]
# Parsing Firefox Sqlite3 Databases
# ---
# Firefox stores these databases in a default directory located at
#
# - Windows: `C:\Documents and Settings\<USER>\Application Data\Mozilla\Firefox\Profiles\<profile folder>\`
# - MacOS: `/Users/<USER>/Library/Application Support/Firefox/Profiles/<profile>/`
# ```
# addons.sqlite		formhistory.sqlite	signons.sqlite
# content-prefs.sqlite	healthreport.sqlite	webappsstore.sqlite
# cookies.sqlite		permissions.sqlite
# extensions.sqlite	places.sqlite
# ```

# %% [markdown]
# Parsing Firefox Sqlite3 Databases
# ---
# Firefox stores these databases in a default directory located at
#
# - Windows: `C:\Documents and Settings\<USER>\Application Data\Mozilla\Firefox\Profiles\<profile folder>\`
# - MacOS: `/Users/<USER>/Library/Application Support/Firefox/Profiles/<profile>/`
# ```
# addons.sqlite		formhistory.sqlite	signons.sqlite
# content-prefs.sqlite	healthreport.sqlite	webappsstore.sqlite
# cookies.sqlite		permissions.sqlite
# extensions.sqlite	places.sqlite
# ```

# %% [markdown]
# Consider, for example, when a user logs onto a web-based email: if the browser could not maintain cookies, the user would have to log on in order to read every individual email. Firefox stores these cookies in a database named <font color="green">cookies.sqlite</font>. If an investigator can extract cookies and reuse them, it provides the opportunity to log on to resources that require authentication.
# ```
#
#                                 No
#     |----------|   cookies? |-------->   log on to read mail
#     | web-basd |  ----------|
#     |  Email   |            |-------->   get data in cookies.sqlite to login automatically
#     |----------|               Yes
#
#
#
# ```
#
#
#
# Let’s write a quick Python script to extract cookies from a user under investigation. We connect to the database and execute our SELECT statement. In the database, the moz_cookies maintains the data regarding cookies. From the moz_cookies table in the cookies.sqlite database, we will query the column values for host, name, and cookie value, and print them to the screen.

# %% [markdown]
# Though the sqlite is created as binany, part of <font color="green">downloads.sqlite</font> should give the details of table what it owns:
# ```
# ...
# CREATE TABLE moz_downloads (id INTEGER PRIMARY KEY, name TEXT, source TEXT, target TEXT, tempPath TEXT, startTime INTEGER, endTime INTEGER, state INTEGER, referrer TEXT, entityID TEXT, currBytes INTEGER NOT NULL DEFAULT 0, maxBytes INTEGER NOT NULL DEFAULT -1, mimeType TEXT, preferredApplication TEXT, preferredAction INTEGER NOT NULL DEFAULT 0, autoResume INTEGER NOT NULL DEFAULT 0)
# ...
# ```
# i.e. the details of created table and its columns are listed as follows:
# ```
#   Table
#       moz_downloads
#   Columns: type/value
#       id: INTEGER (PRIMARY KEY),
#       name: TEXT,
#       source: TEXT,
#       target: TEXT,
#       tempPath: TEXT,
#       startTime: INTEGER,
#       endTime: INTEGER,
#       state: INTEGER,
#       referrer: TEXT,
#       entityID TEXT,
#       currBytes INTEGER NOT NULL DEFAULT 0,
#       maxBytes INTEGER NOT NULL DEFAULT -1,
#       mimeType TEXT,
#       preferredApplication TEXT,
#       preferredAction INTEGER NOT NULL DEFAULT 0,
#       autoResume INTEGER NOT NULL DEFAULT 0
# ```

# %% [markdown]
# Investingate the Sqlite Data
# ---
# - use `Sqlite` library:
# ```
# shell> sqlite3 cookies.sqlite
# SQLite version 3.13.0 2016-05-18 10:57:30
# Enter ".help" for usage hints.
# sqlite> select * from moz_cookies;
# 1|google.com||__utma|29003808.1143615086.1386662234.1386662234.1386662234.1|.mail.google.com|/intl/|1449734236|1386662236729073|1386662233628573|0|0|0|0
# 2|google.com||__utmb|29003808.2.9.1386662236726|.mail.google.com|/intl/|1386664036|1386662236729451|1386662233628903|0|0|0|0
# ...
# ```
# - by Pyhon's sqlite3 library as follows:

# %%
import sqlite3

def printDownloads(downloadDB):
    conn = sqlite3.connect(downloadDB)
    c = conn.cursor()
    c.execute('SELECT name, source, datetime(endTime/1000000,\
    \'unixepoch\') FROM moz_downloads;'
              )
    print('\n[*] --- Files Downloaded --- ')
    for row in c:
        print('[+] File: ' + str(row[0]) + ' from source: ' \
            + str(row[1]) + ' at: ' + str(row[2]))

def printCookies(cookiesDB):
    try:
        conn = sqlite3.connect(cookiesDB)
        c = conn.cursor()
        c.execute('SELECT host, name, value FROM moz_cookies')

        print('\n[*] -- Found Cookies --')
        for row in c:
            host = str(row[0])
            name = str(row[1])
            value = str(row[2])
            print('[+] Host: ' + host + ', Cookie: ' + name \
                + ', Value: ' + value)
    except Exception as e:
        if 'encrypted' in str(e):
            print('\n[*] Error reading your cookies database.')
            print('[*] Upgrade your Python-Sqlite3 Library')

# %%
printDownloads('firefox_profile/downloads.sqlite')
# Out:
# [*] --- Files Downloaded ---
# [+] File: python-nmap-0.1.4.tar.gz from source: http://xael.org/norman/python/python-nmap/python-nmap-0.1.4.tar.gz at: 2012-06-20 02:53:09

# %%
printCookies('Cookies.sqlite')
# Out:
# [*] -- Found Cookies --
# [+] Host: .mail.google.com, Cookie: __utma, Value: 29003808.1143615086.1386662234.1386662234.1386662234.1
# [+] Host: .mail.google.com, Cookie: __utmb, Value: 29003808.2.9.1386662236726
# [+] Host: .mail.google.com, Cookie: __utmz, Value: 29003808.1386662234.1.1.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=icho%20taiwan
# [+] Host: accounts.youtube.com, Cookie: CheckConnectionTempCookie395, Value: 343246
# [+] Host: accounts.google.com, Cookie: ACCOUNT_CHOOSER, Value: AFx_qI5yF-W47GJx05la4a6iPw6WUzFsh9aD8EYkdDWLs22T-iuGw90BK3i24K3rJtP-Jd-xJ-B2k9inNdHB1_SAkd7LdeD8mc2kRK_lWFFWn08C05TXpFpRhjJzSx0ba-xUQody29Eq
# [+] Host: sagecell.sagemath.org, Cookie: accepted_tos, Value: true
# [+] Host: .myweb.hinet.net, Cookie: MyWeb_HostID_L1, Value: twoyears44.myweb.hinet.net
# [+] Host: apis.google.com, Cookie: BEAT, Value: APfa0bqy_ARx8giFGyUS4LB7RwA_GCyvLmpBx_xJtuddXj5UjTDTbiH-FIr6D1EiYHDVvqp-gC7x
# [+] Host: .apple.com, Cookie: ds01_a, Value: d2700059be72ba2434f40f39e3233dc741e53931ce644d707bbc684d0929abaec8846bbeeb28e23294eb7108e7e8b5d27840d44effd98a6b2865ce86e49b377bb3e23859d3bac997d58d3f247385e87efecc09f95cabdbfda33f8f8f4ee9a125GZVX
# [+] Host: developer.apple.com, Cookie: ys-leftpanel, Value: o%3Acollapsed%3Db%253A1
# [+] Host: .developer.apple.com, Cookie: adssuv, Value: Iv2QxBTWC%2Bu7BimTWqY6rp953AnPJA2efS22zoan279JCd3fTZxvuIf06%2BQ7LNymQZi1Vc1r2lHF%0D%0AEeKMrd3Rq5sWJjqsKqJmF%2Bb%2BfI8T9SlM68uv%0D%0A
# [+] Host: pearsonkt.com, Cookie: KAT_WTL_COOKIE_TEST, Value: login
# [+] Host: pearsonkt.com, Cookie: KAT_WTL_LOGIN_URL, Value:
# [+] Host: .pearsonkt.com, Cookie: __utma, Value: 8474548.854533398.1389315134.1389315134.1389315134.1
# [+] Host: .pearsonkt.com, Cookie: __utmb, Value: 8474548.1.10.1389315134
# [+] Host: .pearsonkt.com, Cookie: __utmz, Value: 8474548.1389315134.1.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none)
# [+] Host: www.teachingchannel.org, Cookie: vanity_id, Value: 6002a6c748ce103a5bc0d394f2734445
# [+] Host: .teachingchannel.org, Cookie: optimizelySegments, Value: %7B%7D
# [+] Host: .teachingchannel.org, Cookie: optimizelyEndUserId, Value: oeu1389315156827r0.363661466128427
# [+] Host: .teachingchannel.org, Cookie: optimizelyBuckets, Value: %7B%7D
# [+] Host: .teachingchannel.org, Cookie: mp_30b35361b9b8574db0a23f774e7d78a8_mixpanel, Value: %7B%22distinct_id%22%3A%20%226002a6c748ce103a5bc0d394f2734445%22%2C%22%24search_engine%22%3A%20%22google%22%2C%22%24initial_referrer%22%3A%20%22https%3A%2F%2Fwww.google.com.tw%2Furl%3Fsa%3Dt%26rct%3Dj%26q%3D%26esrc%3Ds%26source%3Dweb%26cd%3D8%26ved%3D0CIgBELcCMAc%26url%3Dhttps%253A%252F%252Fwww.teachingchannel.org%252Fvideos%252Fwriting-to-learn%26ei%3DKUTPUrfDI8mqkwWfooH4Cw%26usg%3DAFQjCNH-c4miDMnpX2UrCcoNK8rlSk4eAw%26sig2%3DPicQBSTUQ4Cd4ZkXRzHCQg%22%2C%22%24initial_referring_domain%22%3A%20%22www.google.com.tw%22%7D
# [+] Host: .www.teachingchannel.org, Cookie: __utma, Value: 140198325.2034095136.1389315157.1389315157.1389315157.1
# [+] Host: .www.teachingchannel.org, Cookie: __utmb, Value: 140198325.1.10.1389315157
# [+] Host: .www.teachingchannel.org, Cookie: __utmz, Value: 140198325.1389315157.1.1.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided)
# [+] Host: .www.teachingchannel.org, Cookie: __utmv, Value: 140198325.|1=Organization=none=1
# [+] Host: .522432557.log.optimizely.com, Cookie: end_user_id, Value: oeu1389315156827r0.363661466128427
# [+] Host: cdns.gigya.com, Cookie: gig3pctest, Value: true
# [+] Host: .teachingchannel.org, Cookie: gig3pc, Value: 1
# [+] Host: .gigya.com, Cookie: ucid, Value: XFXM2OOmlGQl4NsAOb+v5A==
# [+] Host: .teachingchannel.org, Cookie: optimizelyPendingLogEvents, Value: %5B%5D
# [+] Host: www.teachingchannel.org, Cookie: displayed_registration_prompt, Value: true
# [+] Host: .plurk.com, Cookie: __cfduid, Value: dfd7ed2bb9c76e116870511172fec40881400659686077
# [+] Host: .mozilla.com.tw, Cookie: __utma, Value: 244153625.950510825.1400659686.1400659686.1400659686.1
# [+] Host: .mozilla.com.tw, Cookie: __utmb, Value: 244153625.2.10.1400659686
# [+] Host: .mozilla.com.tw, Cookie: __utmz, Value: 244153625.1400659686.1.1.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided)
# [+] Host: .pinterest.com, Cookie: _pinterest_cm, Value: "eJwzicpMznUxCC9M9fZINnGvdIsqrvR1T3bKcXe0tY8vycxNtfXMcsxUK81LLC3JiM9MsfXMjTT0d0kujwxJL/fLSjf0rQrK9gt3NfUNDzTxcweyXVIy/F3STfxCQss9021tAXmkIR4="
# [+] Host: .stackoverflow.com, Cookie: prov, Value: 9de5f6fe-e304-4762-a876-34bc39b7d633
# [+] Host: .sstatic.net, Cookie: __cfduid, Value: d2f1b142200da0974b35cf4bbc1a95dad1400659734390
# [+] Host: .imgur.com, Cookie: __cfduid, Value: d7cdf666ac8d1e58d616cc4212efd61771400659734507
# [+] Host: .stackoverflow.com, Cookie: __qca, Value: P0-2146447433-1400659734640
# [+] Host: .scorecardresearch.com, Cookie: UID, Value: 366e5303-203.69.141.9-1400659734
# [+] Host: .scorecardresearch.com, Cookie: UIDR, Value: 1400659734
# [+] Host: .quantserve.com, Cookie: mc, Value: 537c5f16-ae908-ce406-b7cb2
# [+] Host: .docs.google.com, Cookie: S, Value: comments=81wzCi8iQJ8vAx7_jC-8Wg
# [+] Host: .tools.android.com, Cookie: _ga, Value: GA1.3.2062420484.1400133043
# [+] Host: tools.android.com, Cookie: aftzc, Value: QW1lcmljYS9Mb3NfQW5nZWxlczp3eGRhd0FxcWxWZkNYdHRkVVJ2ZStlVEpOOVE9
# [+] Host: .tools.android.com, Cookie: __utma, Value: 153939517.2062420484.1400133043.1400133044.1404429273.2
# [+] Host: .tools.android.com, Cookie: __utmb, Value: 153939517.2.10.1404429273
# [+] Host: .tools.android.com, Cookie: __utmz, Value: 153939517.1400133044.1.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none)
# [+] Host: .oracle.com, Cookie: gpv_p24, Value: no%20value
# [+] Host: .eloqua.com, Cookie: ELOQUA, Value: GUID=11F50B416D874BA687BF1B12D806D351
# [+] Host: .eloqua.com, Cookie: ELQSTATUS, Value: OK
# [+] Host: .oracle.com, Cookie: oraclelicense, Value: accept-securebackup-cookie
# [+] Host: .oracle.com, Cookie: s_nr, Value: 1404430251410
# [+] Host: .oracle.com, Cookie: gpw_e24, Value: http%3A%2F%2Fwww.oracle.com%2Ftechnetwork%2Fjava%2Fjavase%2Fdownloads%2Fjdk7-downloads-1880260.html
# [+] Host: .edelivery.oracle.com, Cookie: ARU_LANG, Value: US
# [+] Host: developer.android.com, Cookie: android_developer_pref_lang, Value: en
# [+] Host: .doubleclick.net, Cookie: id, Value: 221daa0c2f0300ac||t=1404971304|et=730|cs=002213fd484e9ac57fbf6302a6
# [+] Host: .maciku.blogspot.com, Cookie: NCR, Value: 1
# [+] Host: .js1.bloggerads.net, Cookie: ICLICK_SESSIONID, Value: -1760021434.w4huuBtE
# [+] Host: .linkwithin.com, Cookie: ssid, Value: mDQow5g0CJxhtiPQkKDiCczKihiT0R
# [+] Host: maciku.blogspot.com, Cookie: HstCfa893722, Value: 1404971388007
# [+] Host: maciku.blogspot.com, Cookie: HstCla893722, Value: 1404971388007
# [+] Host: maciku.blogspot.com, Cookie: HstCmu893722, Value: 1404971388007
# [+] Host: maciku.blogspot.com, Cookie: HstPn893722, Value: 1
# [+] Host: maciku.blogspot.com, Cookie: HstPt893722, Value: 1
# [+] Host: maciku.blogspot.com, Cookie: HstCnv893722, Value: 1
# [+] Host: maciku.blogspot.com, Cookie: HstCns893722, Value: 1
# [+] Host: maciku.blogspot.com, Cookie: c_ref_893722, Value: http%3A%2F%2Fmaciku.blogspot.tw%2F2010%2F11%2Fmac-osx-android-sdk-eclipseadtandroid.html
# [+] Host: .histats.com, Cookie: CountUid, Value: c8873400-7dlm-4935-ba5c-b293c5b4521b
# [+] Host: .maciku.blogspot.com, Cookie: __utma, Value: 78365064.710959898.1404971387.1404971387.1404971387.1
# [+] Host: .maciku.blogspot.com, Cookie: __utmb, Value: 78365064.1.10.1404971390
# [+] Host: .maciku.blogspot.com, Cookie: __utmz, Value: 78365064.1404971390.1.1.utmcsr=maciku.blogspot.tw|utmccn=(referral)|utmcmd=referral|utmcct=/2010/11/mac-osx-android-sdk-eclipseadtandroid.html
# [+] Host: .yahoo.com, Cookie: B, Value: 07celll9rsabu&b=3&s=9o
# [+] Host: .android.com, Cookie: _ga, Value: GA1.2.1713141845.1404971305
# [+] Host: .mathjax.org, Cookie: __cfduid, Value: d4820e3bfde22352aadf8e9ef31b0581c1404973217858
# [+] Host: www.cgu.edu.tw, Cookie: PageLang, Value: zh-tw
# [+] Host: el.cgu.edu.tw, Cookie: forum_sortby, Value: pt
# [+] Host: www.ksnews.com.tw, Cookie: __atuvc, Value: 1%7C28
# [+] Host: .addthis.com, Cookie: di2, Value: N8HIY3.UYM
# [+] Host: .addthis.com, Cookie: dt, Value: X
# [+] Host: tw.news.yahoo.com, Cookie: ywandp, Value: 10001703162079%3A1640046942
# [+] Host: ads.yahoo.com, Cookie: uid, Value: uid=88ea11ea-0802-11e4-9c46-0b2e6ad83594&_hmacv=1&_salt=4237468578&_keyid=k1&_hmac=4af9a9ef636647b2158ed2529a90007045377375
# [+] Host: tw.news.yahoo.com, Cookie: fpc, Value: 10001703162079%3AZVyZS0-P%7CDE6qFH3Naa%7Cfses10001703162079%3D%7CDE6qFH3Naa%7CZVyZS0-P%7Cfvis10001703162079%3D%7C8TYT7H0HHY%7C8TYT7H0HHY%7C8TYT7H0HHY%7C8%7C8TYT7H0HHY%7C8TYT7H0HHY
# [+] Host: .yahoo.com, Cookie: V, Value: v=0.7&m=0&ccOptions=%7B%22show%22%3Afalse%2C%22lang%22%3A%22en%22%2C%22fontSize%22%3A24%2C%22fontName%22%3A%22Helvetica%20Neue%2CHelvetica%2CArial%2C_sans%22%2C%22fontColor%22%3A%22%23ffffff%22%2C%22fontOpacity%22%3A1%2C%22fontEffect%22%3A%22none%22%2C%22bgColor%22%3A%22%23000000%22%2C%22bgOpacity%22%3A0.75%7D
# [+] Host: tw.news.yahoo.com, Cookie: ywadp115488662, Value: 114556580
# [+] Host: tw.news.yahoo.com, Cookie: N4YR, Value: s=8
# [+] Host: .scorecardresearch.com, Cookie: CP3, Value: 1
# [+] Host: .tianyaclub.com, Cookie: time, Value: ct=1404976813.14
# [+] Host: topic.tianyaclub.com, Cookie: __ptime, Value: 1404976813691
# [+] Host: topic.tianyaclub.com, Cookie: __cid, Value: TW
# [+] Host: topic.tianyaclub.com, Cookie: __guid, Value: 1855406328
# [+] Host: topic.tianyaclub.com, Cookie: __guid2, Value: 1855406328
# [+] Host: .tianya.cn, Cookie: __ptime, Value: 1404976817491
# [+] Host: .dol.tianya.cn, Cookie: ADVC, Value: 31ea3091f61445
# [+] Host: .dol.tianya.cn, Cookie: ASL, Value: 16261,0000p,787e164d
# [+] Host: .hm.baidu.com, Cookie: HMACCOUNT, Value: 0C6F7AC38131D630
# [+] Host: .tianya.cn, Cookie: Hm_lvt_bc5755e0609123f78d0e816bf7dee255, Value: 1404976818
# [+] Host: .tianya.cn, Cookie: __cid, Value: TW
# [+] Host: .tianya.cn, Cookie: time, Value: ct=1404976817.765
# [+] Host: .gostats.cn, Cookie: sessionID.4.387344, Value: 894389780
# [+] Host: .gostats.cn, Cookie: visitorID, Value: 1848258341
# [+] Host: .tianya.cn, Cookie: __guid, Value: 1992480898
# [+] Host: .tianya.cn, Cookie: __guid2, Value: 1992480898
# [+] Host: .baidu.com, Cookie: BAIDUID, Value: 3661D12FA0686FE2C61DABA39B4AEFB2:FG=1
# [+] Host: cpro.baidustatic.com, Cookie: CPROID, Value: 5DF5AD6A4123796E497088FE4CDF3C9A:FG=1
# [+] Host: .pos.baidu.com, Cookie: CPROID, Value: 5DF5AD6A4123796E497088FE4CDF3C9A:FG=1
# [+] Host: pos.baidu.com, Cookie: ISBID, Value: 3661D12FA0686FE2C61DABA39B4AEFB2:FG=1
# [+] Host: pos.baidu.com, Cookie: ISUS, Value: 5DF5AD6A4123796E497088FE4CDF3C9A:FG=1
# [+] Host: .facebook.com, Cookie: x-src, Value: %2Fshinyshinewl%7Cpagelet_search_results
# [+] Host: .tw100s.com, Cookie: __cfduid, Value: d3873ef9c9eca667c75bee476b7c82b4f1404977248106
# [+] Host: .mmstat.com, Cookie: cna, Value: YS5FDPZFAjgCAXh+Fk0WJue5
# [+] Host: .trackeyword.com, Cookie: __cfduid, Value: daff1b83a0ffb60b3b1b3188f8be6594f1404977249587
# [+] Host: .blog.xuite.net, Cookie: __utma, Value: 243393110.732300173.1404977281.1404977281.1404977281.1
# [+] Host: .blog.xuite.net, Cookie: __utmb, Value: 243393110.1.10.1404977281
# [+] Host: .blog.xuite.net, Cookie: __utmz, Value: 243393110.1404977281.1.1.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided)
# [+] Host: p8u.hinet.net, Cookie: NGUserID, Value: ac103708-4357-1961416457-1404977280
# [+] Host: track.xuite.net, Cookie: track, Value: 866196682
# [+] Host: .xuite.net, Cookie: __asc, Value: 93a568cd1471f2bf7bbe513b524
# [+] Host: .xuite.net, Cookie: __auc, Value: 93a568cd1471f2bf7bbe513b524
# [+] Host: .blog.xuite.net, Cookie: INT_YRMUMU, Value: Y_rmumu=1:
# [+] Host: .fc2.com, Cookie: bloguid, Value: c2eae790-f361-4032-82de-a01fdf35a2d6
# [+] Host: vwnpgadr.blog132.fc2.com, Cookie: cookietest, Value: test
# [+] Host: www.tw100s.com, Cookie: CNZZDATA5778765, Value: cnzz_eid%3D1008770461-1404977248-http%253A%252F%252Fwww.google.com.tw%252F%26ntime%3D1404977248
# [+] Host: .tw100s.com, Cookie: __utma, Value: 203760661.1238753003.1404977249.1404977249.1404977249.1
# [+] Host: .tw100s.com, Cookie: __utmb, Value: 203760661.2.10.1404977249
# [+] Host: .tw100s.com, Cookie: __utmz, Value: 203760661.1404977249.1.1.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided)
# [+] Host: .cnzz.mmstat.com, Cookie: atpsida, Value: fd320fe3d9415c03e646d1f7_1404977485
# [+] Host: .cnzz.com, Cookie: cna, Value: YS5FDPZFAjgCAXh+Fk0WJue5
# [+] Host: .wretch.cc, Cookie: BX, Value: bh5np319rsgau&b=3&s=ar
# [+] Host: tw.yahoo.com, Cookie: exp_32058561_140710, Value: exp_32058561_140710
# [+] Host: tw.yahoo.com, Cookie: exp_32058561_140710.adExpire, Value: Fri%20Jul%2011%202014%2015%3A31%3A44%20GMT%2B0800%20(CST)
# [+] Host: tw.yahoo.com, Cookie: exp_32058561_140710.adTimes, Value: 3
# [+] Host: .yahoo.com, Cookie: HP, Value: 0
# [+] Host: .pixnet.net, Cookie: lang, Value: zh_TW
# [+] Host: .pixnet.cc, Cookie: PIXSID, Value: cr74nc2ht8ketp1ls3g6c2qf31
# [+] Host: .pixanalytics.com, Cookie: _pta, Value: CgEBVVO+QXN53WduE83DAg==
# [+] Host: .pixnet.net, Cookie: mp_9d3f1e7b0d94a9006738af20b0278f6f_mixpanel, Value: %7B%22distinct_id%22%3A%20%221471f2fab8fd5f-082bd7af62c4f18-40612842-fa000-1471f2fab90a87%22%2C%22%24search_engine%22%3A%20%22google%22%2C%22%24initial_referrer%22%3A%20%22http%3A%2F%2Fwww.google.com.tw%2Furl%3Fsa%3Dt%26rct%3Dj%26q%3D%26esrc%3Ds%26source%3Dweb%26cd%3D42%26ved%3D0CCUQFjABOCg%26url%3Dhttp%253A%252F%252Fwww.pixnet.net%252Fblog%252Fprofile%252Fivonie7788%26ei%3DbUG-U8CVAYXVkwXe-IDICw%26usg%3DAFQjCNFupdbsLk3aucv0c_lE3zngz9O8iA%26sig2%3DEA-odUHMC9qQGyQBg8VoEw%22%2C%22%24initial_referring_domain%22%3A%20%22www.google.com.tw%22%7D
# [+] Host: .ivonie7788.pixnet.net, Cookie: PIXFRONTID, Value: 12gi6dmau8d4c9uhussni23hu5
# [+] Host: .plurk.com, Cookie: plurkcookiea, Value: "7yXuo8xkZHcH0zNhKmwiVthnXhM=?user_ip=UycxMjAuMTI2LjIyLjc3JwpwMQou"
# [+] Host: .funnygirlqq.pixnet.net, Cookie: PIXFRONTID, Value: 0fpqboe5qjdm4ngffl5fci4sr5
# [+] Host: .7headlines.com, Cookie: 7headlines, Value: imasbs5u1nnnf03cfpij39ha64
# [+] Host: .tags.pixnet.net, Cookie: PIXTAGS, Value: tb1s4jug7u81q2f6ir4ecb83n3
# [+] Host: .coco157.pixnet.net, Cookie: PIXFRONTID, Value: rqqh267go99inok4j305t5c5r5
# [+] Host: coco157.pixnet.net, Cookie: __utma, Value: 1.1550460925.1404977772.1404977772.1404977772.1
# [+] Host: coco157.pixnet.net, Cookie: __utmb, Value: 1.10.10.1404977772
# [+] Host: coco157.pixnet.net, Cookie: __utmz, Value: 1.1404977772.1.1.utmcsr=tags.pixnet.net|utmccn=(referral)|utmcmd=referral|utmcct=/blog/user/funnygirlQQ/%E6%9E%97%E4%BA%9E%E7%92%87
# [+] Host: coco157.pixnet.net, Cookie: __utmv, Value: 1.nonVIP
# [+] Host: funnygirlqq.pixnet.net, Cookie: __utma, Value: 1.1417022661.1404977742.1404977742.1404977742.1
# [+] Host: funnygirlqq.pixnet.net, Cookie: __utmb, Value: 1.10.10.1404977742
# [+] Host: funnygirlqq.pixnet.net, Cookie: __utmz, Value: 1.1404977742.1.1.utmcsr=pixnet.net|utmccn=(referral)|utmcmd=referral|utmcct=/blog/profile/ivonie7788
# [+] Host: funnygirlqq.pixnet.net, Cookie: __utmv, Value: 1.nonVIP
# [+] Host: .7headlines.com, Cookie: mp_0aad5c129e2b0ce98e1efa1651ad0cfd_mixpanel, Value: %7B%22distinct_id%22%3A%20%221471f33007abb0-0e2c0a6c7cda5c8-40612842-fa000-1471f33007b65e%22%2C%22%24initial_referrer%22%3A%20%22http%3A%2F%2Ffunnygirlqq.pixnet.net%2Fblog%2Fpost%2F100407986%22%2C%22%24initial_referring_domain%22%3A%20%22funnygirlqq.pixnet.net%22%7D
# [+] Host: .7headlines.com, Cookie: __asc, Value: a0df5bd21471f33002849b9777d
# [+] Host: .7headlines.com, Cookie: __auc, Value: a0df5bd21471f33002849b9777d
# [+] Host: .7headlines.com, Cookie: __utma, Value: 168880551.2138113524.1404977742.1404977742.1404977742.1
# [+] Host: .7headlines.com, Cookie: __utmb, Value: 168880551.4.10.1404977742
# [+] Host: .doublemax.net, Cookie: dm_bt, Value: 11%3A20%2C23%3A20%2C17%3A20%2C16%3A20%2C18%3A20%20%2Bw8HlxEr3ZIUzxXquw%2Bc%2BQ8EYdE1H%2BKe13psdO3HFzg
# [+] Host: .doublemax.net, Cookie: uuid_qy, Value: 173338588355203686
# [+] Host: .doublemax.net, Cookie: __utma, Value: 138251301.1301064894.1404978571.1404978571.1404978571.1
# [+] Host: .doublemax.net, Cookie: __utmb, Value: 138251301.2.10.1404978571
# [+] Host: .doublemax.net, Cookie: __utmz, Value: 138251301.1404978571.1.1.utmcsr=sitetag.us|utmccn=(referral)|utmcmd=referral|utmcct=/garyfrog2001/%E9%95%B7%E5%BA%9A%20%E5%B0%9A%E7%9C%9F%20%E7%B5%90%E5%A9%9A%E4%BA%86
# [+] Host: .doublemax.net, Cookie: uuid, Value: 454411374255550880
# [+] Host: .sitetag.us, Cookie: __utma, Value: 209239440.1380453863.1404978527.1404978527.1404978527.1
# [+] Host: .sitetag.us, Cookie: __utmb, Value: 209239440.3.10.1404978527
# [+] Host: .sitetag.us, Cookie: __utmz, Value: 209239440.1404978527.1.1.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided)
# [+] Host: .pixnet.net, Cookie: __asc, Value: 72436a6b1471f2faa3b4ad6cc2f
# [+] Host: .pixnet.net, Cookie: __auc, Value: 72436a6b1471f2faa3b4ad6cc2f
# [+] Host: .pixnet.net, Cookie: mp_de68fb7561d61e2fa21b5d584e246ede_mixpanel, Value: %7B%22distinct_id%22%3A%20%221471f30b3142c5-01e18d6e3fd6418-40612842-fa000-1471f30b316f24%22%2C%22%24initial_referrer%22%3A%20%22http%3A%2F%2Fwww.pixnet.net%2Fblog%2Fprofile%2Fivonie7788%22%2C%22%24initial_referring_domain%22%3A%20%22www.pixnet.net%22%2C%22%24search_engine%22%3A%20%22google%22%7D
# [+] Host: .pixnet.net, Cookie: mp_9bf666011f2e0d6e333f9bfa242d0c21_mixpanel, Value: %7B%22distinct_id%22%3A%20%221471f30b319df7-0852f9965988618-40612842-fa000-1471f30b31a13d9%22%2C%22%24initial_referrer%22%3A%20%22http%3A%2F%2Fwww.pixnet.net%2Fblog%2Fprofile%2Fivonie7788%22%2C%22%24initial_referring_domain%22%3A%20%22www.pixnet.net%22%2C%22%24search_engine%22%3A%20%22google%22%7D
# [+] Host: ivonie7788.pixnet.net, Cookie: __utma, Value: 1.525277110.1404977591.1404977591.1404978619.2
# [+] Host: ivonie7788.pixnet.net, Cookie: __utmb, Value: 1.5.10.1404978619
# [+] Host: ivonie7788.pixnet.net, Cookie: __utmz, Value: 1.1404978619.2.2.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided)
# [+] Host: ivonie7788.pixnet.net, Cookie: __utmv, Value: 1.nonVIP
# [+] Host: .adsame.com, Cookie: ASID, Value: 31ea34dc8e505e
# [+] Host: .adsame.com, Cookie: ASL, Value: 16261,0000p,787e164d
# [+] Host: .scupio.com, Cookie: scwc5, Value: H4sIAKW2vlMA_-Pi4ZAWYJNiMzQxMDc0AACJOf5iDgAAAA
# [+] Host: .scupio.com, Cookie: vch, Value: 4094,1^4740,1^4094,2^4740,1^5583,1
1.1.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided)
# [+] Host: .www.wordreference.com, Cookie: per24h, Value: 1
# [+] Host: .wordreference.com, Cookie: wrexpire, Value: 0
# [+] Host: .tutorialspoint.com, Cookie: __utma, Value: 55973678.1554407406.1405310914.1405310914.1405310914.1
# [+] Host: .tutorialspoint.com, Cookie: __utmb, Value: 55973678
# [+] Host: .tutorialspoint.com, Cookie: __utmz, Value: 55973678.1405310914.1.1.utmccn=(organic)|utmcsr=google|utmctr=|utmcmd=organic
# [+] Host: www.tutorialspoint.com, Cookie: __atuvc, Value: 1%7C29
# [+] Host: .mozilla.org, Cookie: optimizelyEndUserId, Value: oeu1405411461929r0.07789361980079446
# [+] Host: .246059135.log.optimizely.com, Cookie: end_user_id, Value: oeu1405411461929r0.07789361980079446
# [+] Host: .twitter.com, Cookie: guest_id, Value: v1%3A140548102704753104
# [+] Host: .pixelmator.com, Cookie: _ga, Value: GA1.2.144983908.1405481026
# [+] Host: .pydata.org, Cookie: _ga, Value: GA1.2.2065128928.1405481087
# [+] Host: .linkedin.com, Cookie: bcookie, Value: "v=2&9901439a-e2a4-462b-8fa4-16dd2a2f00c9"
# [+] Host: .www.linkedin.com, Cookie: bscookie, Value: "v=1&201407160326320a00dc5c-d9fe-45ce-8476-bd63a9895305AQH8nqqxGKNINkpJL2kMZdQnJaP7EHSd"
# [+] Host: .slideshare.net, Cookie: _uv_id, Value: 1782653391
# [+] Host: .slideshare.net, Cookie: __utma, Value: 186399478.1792236583.1405481191.1405481191.1405481191.1
# [+] Host: .slideshare.net, Cookie: __utmb, Value: 186399478.23.6.1405481211003
# [+] Host: .slideshare.net, Cookie: __utmz, Value: 186399478.1405481191.1.1.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided)
# [+] Host: .slideshare.net, Cookie: __utmv, Value: 186399478.non-member|1=member_type=LOGGEDOUT=1
# [+] Host: .slideshare.net, Cookie: RT, Value: cl=1405481210988&r=http%3A%2F%2Fwww.slideshare.net%2FPyData%2Fpydata-london-bokeh-tutorial-bryan-van-de-ven&nu=http%3A%2F%2Fwww.slideshare.net%2FPyData%2Fpydata-london-bokeh-tutorial-bryan-van-de-ven%23btnNext&ul=1405481213359&hd=1405481213641
# [+] Host: .appledaily.com.tw, Cookie: __gads, Value: ID=97bfbd6786dbfbad:T=1405481600:S=ALNI_MYEURJauw-hkLBdmf-W0Gv5BQ6ozg
# [+] Host: .serving-sys.com, Cookie: C4, Value:
# [+] Host: .serving-sys.com, Cookie: D1, Value:
# [+] Host: www.appledaily.com.tw, Cookie: _cb_ls, Value: 1
# [+] Host: .bs.serving-sys.com, Cookie: eyeblaster, Value: FLV=0&RES=1024
# [+] Host: www.appledaily.com.tw, Cookie: _v__chartbeat3, Value: zGxZCkPtqSBM8Az4
# [+] Host: www.appledaily.com.tw, Cookie: _v__cb_cp, Value: CwIy2c-JycSC_Xe4lCp4X-SCjvtBJ
# [+] Host: .wtp101.com, Cookie: cookie_born, Value: 1405481722
# [+] Host: .send.microad-cn.com, Cookie: GCM, Value: 2
# [+] Host: .rtbidder.net, Cookie: uid, Value: OS3uidZ53c5f33036faccab8fdf9867%21S2tskwMfxTB%21%24C1BUzLjqADJKgu3qOicufHzpA..%21
# [+] Host: .simpli.fi, Cookie: uid, Value: 3RpRKX4C8vN6bi3I5KQBQB%3D%3D
# [+] Host: .tidaltv.com, Cookie: tidal_ttid, Value: ed46e634-5df5-4f28-b6fd-b321274fa4d5
# [+] Host: .alibaba.com, Cookie: ali_apache_track, Value:
# [+] Host: ynuf.alibaba.com, Cookie: umdata_, Value: B8EECC70771A2D53FAADE6B9E66A06347CBD4B5D9E8338A5E7CEBD36310261F9AE978E3DFAEDB3F43EC8B115C494095F1A9565CCE2248204283F3692E243741C899A21E722CBE078
# [+] Host: www.alibaba.com, Cookie: _umdata, Value: B8EECC70771A2D53FAADE6B9E66A06347CBD4B5D9E8338A5E7CEBD36310261F9AE978E3DFAEDB3F43EC8B115C494095F1A9565CCE2248204283F3692E243741C899A21E722CBE078
# [+] Host: .www.toysrus.com, Cookie: __g_u, Value: 92603944612546_0
# [+] Host: .toysrus.com, Cookie: mbox, Value: check#true#1405490521|session#1405490460220-737230#1405492321
# [+] Host: www.toysrus.com, Cookie: ClrCSTO, Value: T
# [+] Host: www.toysrus.com, Cookie: ClrSSID, Value: 1405490462712-29922
# [+] Host: www.toysrus.com, Cookie: ClrOSSID, Value: 1405490462712-29922
# [+] Host: www.toysrus.com, Cookie: ClrSCD, Value: 1405490462713
# [+] Host: .toysrus.com, Cookie: s_vs, Value: 1
# [+] Host: .toysrus.com, Cookie: s_cpm, Value: %5B%5B'ToysRUs%2520Subdomain'%2C'1405490462760'%5D%5D
# [+] Host: .toysrus.com, Cookie: s_nr, Value: 1405490462761
# [+] Host: .toysrus.com, Cookie: __utma, Value: 136881205.1159220264.1405490463.1405490463.1405490463.1
# [+] Host: .toysrus.com, Cookie: __utmb, Value: 136881205.1.10.1405490463
# [+] Host: .toysrus.com, Cookie: __utmz, Value: 136881205.1405490463.1.1.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided)
# [+] Host: .dsa.csdata1.com, Cookie: tpc, Value: 943edc3d0f3e00001e15c6539bf20c00a0000000
# [+] Host: media.gsimedia.net, Cookie: ub_49, Value: bid=222228326745&uid=0&fvd=1405490463&lvd=1405490463&nov=1&ordAmt=0&lOrdDate=0&lOrdPids=0&rvPid=0&rvCid=2257646&sKw=0&cPid=0&cDt=0&cAmt=0&wlPids=0&wlDate=0&sId=312703445&mks=0&curr=USD&oId=0
# [+] Host: .hlserve.com, Cookie: hmGUID, Value: 3996248a-cd0d-47ac-8d97-ff556d98d6d8
# [+] Host: .owneriq.net, Cookie: ss, Value:
# [+] Host: .owneriq.net, Cookie: rpq, Value: .
# [+] Host: .owneriq.net, Cookie: si, Value: Q4587768631301654689
# [+] Host: .owneriq.net, Cookie: p1, Value: 3563580568.2460863690.2460863685.3563580573.3563580563
# [+] Host: .owneriq.net, Cookie: gguuid, Value: CAESEIq6KGNHZEWCFYwW9IBQX8A
# [+] Host: .owneriq.net, Cookie: rmuuid, Value: _Zziov094VMknrmN7dwG2xQI
# [+] Host: .owneriq.net, Cookie: apq, Value: .
# [+] Host: .toysrus.com, Cookie: s_vi, Value: [CS]v1|29E30A8F85148D7D-4000017520125C11[CE]
# [+] Host: .adnxs.com, Cookie: anj, Value: dTM7k!M4/Ag1yl1e6AqeU2lh@'ABWkVPXCnQ%%m3YbU4:!9?75]=/Y!]?:#ItrRv_AUMcr>8LzpgKzi4f9+ziQ0Wc_'5I%]#xYE>Xj=A-*3)EH.eF6#+`mS#gVwuK5@g?n_7M$/m-Y)$
# [+] Host: .toysrus.com, Cookie: OAX, Value: R3l7YVPGFSAABJIh
# [+] Host: www.toysrus.com, Cookie: OAX_tmp, Value: 52336c375956504746534141424a4968
# [+] Host: .toysrus.com, Cookie: RES_TRACKINGID, Value: 13825304846409450
# [+] Host: .toysrus.com, Cookie: RES_SESSIONID, Value: 10141214846409450
# [+] Host: www.toysrus.com, Cookie: browser_id, Value: 222228687195
# [+] Host: .gsimedia.net, Cookie: PrefID, Value: 132-791917957
# [+] Host: www.toysrus.com, Cookie: 92148650-VID, Value: 112880309126008
# [+] Host: en.wikipedia.org, Cookie: centralnotice_bucket, Value: 1-4.2
# [+] Host: en.wikipedia.org, Cookie: enwiki-gettingStartedUserId, Value: KfclSmbZp1NLLH2WLOdNe3ScmJdGINnO
# [+] Host: www.ask.com, Cookie: dmid, Value: 3dc6712d-0a5c-ad8d-3173-2b566416eeda
# [+] Host: .ask.com, Cookie: ld_USR, Value: 0E1F4E7236D1C06A79112DEE798E77ED146
# [+] Host: .ask.com, Cookie: ld_SSN, Value: 0112427E3ED1C06A79112DEE798E77ED146
# [+] Host: .ask.com, Cookie: oo, Value: 102140
# [+] Host: www.ask.com, Cookie: OX_sd, Value: 1
# [+] Host: .ask.com, Cookie: uc, Value: "u=F03BC540-3BB2-4A50-9722-771ADB87F1AF&fv=1405490721063&lv=1405490721066&nv=2&sn=seofe007iad.io.askjeeves.info&od=google.com.tw&ok=-&w=1440&h=900&cd=24&op=-"
# [+] Host: .ask.com, Cookie: __utma, Value: 252994457.1359350805.1405490723.1405490723.1405490723.1
# [+] Host: .ask.com, Cookie: __utmb, Value: 252994457.1.10.1405490724
# [+] Host: .ask.com, Cookie: __utmz, Value: 252994457.1405490724.1.1.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided)
# [+] Host: ox-d.ask.servedbyopenx.com, Cookie: OX_u, Value: 1aed45a7-8eee-0bf8-013d-c05a5c3ba3b5_m_1406700324
# [+] Host: .p-td.com, Cookie: uid, Value: 4123701360079393667
# [+] Host: .audienceiq.com, Cookie: uid, Value: 3064104131518216760
# [+] Host: www.ask.com, Cookie: __atuvc, Value: 1%7C29
# [+] Host: .bizographics.com, Cookie: BizoID, Value: a1115917-5fb4-4981-8217-f9a0a8aaa818
# [+] Host: .bizographics.com, Cookie: BizoData, Value: ...
# [+] Host: badge.stumbleupon.com, Cookie: su_bc, Value: 1
# [+] Host: .addthis.com, Cookie: uit, Value: 1
# [+] Host: .rlcdn.com, Cookie: ck1, Value: ck1
# [+] Host: .ask.com, Cookie: __gads, Value: ID=63aace4d046f402b:T=1405490725:S=ALNI_MavwbImO5uO_hTPx4Sb36eZn122Qw
# [+] Host: .adsymptotic.com, Cookie: U, Value: 6eba81824f5b2d1eda3bcf32d8f003f1
# [+] Host: .impact-ad.jp, Cookie: tuuid, Value: 1600ddc0-0840-4243-930c-6755d3fc80c4
# [+] Host: .pubmatic.com, Cookie: KRTBCOOKIE_27, Value: 1216-uid:f77c53c5-f364-4500-9c6c-c68c2c05133a
# [+] Host: .krxd.net, Cookie: ServedBy, Value: beacon-a069
# [+] Host: .krxd.net, Cookie: _kuid_, Value: JOEREMyc
# [+] Host: .criteo.com, Cookie: uid, Value: 33b88a46-18c0-457c-9d13-1ccca6290972
# [+] Host: .criteo.com, Cookie: eid, Value: *1QOnnboZH3qZAa2ZiHZo2BxwpBzPbWui7CYoox0I83T%2fR4BupYZDtpmUKKm%2b49SF%2f
# [+] Host: ads.yahoo.com, Cookie: bh, Value: "b!!!!'!!vUs!!!!#>rfJL!#w>5!!!!#>rfac!$iFG!!!!#>sWRs!%QY0!!!!#>sWV%"
# [+] Host: .rubiconproject.com, Cookie: rpb, Value: 4222%3D1
# [+] Host: .pixel.rubiconproject.com, Cookie: rpx, Value: 4222%3D39766%2C0%2C1%2C%2C
# [+] Host: .rubiconproject.com, Cookie: put_1512, Value: f77c53c5-f364-4500-9c6c-c68c2c05133a
# [+] Host: .lijit.com, Cookie: ljt_reader, Value: d25b9a44a487d1b6e015db9d6b4bc537
# [+] Host: .lijit.com, Cookie: ljtrtb, Value: "eJyrrgUAAXUA%2BQ%3D%3D"
# [+] Host: .lijit.com, Cookie: _ljtrtb_3, Value: f77c53c5-f364-4500-9c6c-c68c2c05133a
# [+] Host: .adap.tv, Cookie: rtbData0, Value: "key=mediamathinc:value=f77c53c5-f364-4500-9c6c-c68c2c05133a:expiresAt=Thu+Aug+14+23%3A05%3A28+PDT+2014:32-Compatible=true"
# [+] Host: .agkn.com, Cookie: uuid, Value: 1068738280362159287
# [+] Host: .agkn.com, Cookie: u, Value: B|0SAIbWNKoG1jSqAAAAAAAAAABAmcAAAAkZjc3YzUzYzUtZjM2NC00NTAwLTljNmMtYzY4YzJjMDUxMzNhAAA
# [+] Host: .burstnet.com, Cookie: BI77161, Value: f77c53c5-f364-4500-9c6c-c68c2c05133a
# [+] Host: .rlcdn.com, Cookie: rlas3, Value: "tuOZlgpY6VxLYYOU8PJju2YxIfX7eGjsLbNXBG3yGms="
# [+] Host: .rlcdn.com, Cookie: rtn1, Value: 508328841060e3059271bb2d5629cf7ebe09672b2d04355ca949a2c722bc444fdaa3b26eef3ec29bc81eed210b5788a5ad9c7cb69ed761fc
# [+] Host: .rlcdn.com, Cookie: dids1567918704, Value: 
# [+] Host: .zenoviaexchange.com, Cookie: _zdeuuid, Value: %7B%22zde_uuid%22%3A%22XU01v04-50eb3e22-f92f-4960-9ed4-75f34e9d3d0f%22%2C%22zdxidn%22%3Afalse%7D
# [+] Host: ih.adscale.de, Cookie: tu, Value: 2#2790145180#39~f77c53c5-f364-4500-9c6c-c68c2c05133a~16267~0
# [+] Host: .adscale.de, Cookie: uu, Value: 425591405490728096
# [+] Host: .admaym.com, Cookie: UM1, Value: RgAAAB-LCAAAAAAAAAvjcuHQFnLgUkkzN082NU421U0zNjPRNTE1MNC1TDZL1k02s0g2SjYwNTQ2ThTi5mhYfuXW-p3fDQVYpUCcW7NfbfkJ5AAAkqTfW0YAAAA1
# [+] Host: .admaym.com, Cookie: vi, Value: 8f516279d34c4881b83fc40ca1a75f7c
# [+] Host: .admaym.com, Cookie: fid, Value: 8098192620decef11aeb9b908204b74e
# [+] Host: .spotxchange.com, Cookie: partner-0, Value: eNptzE0LglAQheF1%2FZdAvXoDoYWlyRXHwY%2FUcZdCoWUGCeb8%2BqS2Lc7mhfNIaYmVvZfmJvUS5YSq8lybsoHxMTJ2nsA2mKgMtLrP51LkXJXBpfKPGqVq2%2FAwYataFCAhc6Tqc7Px7zOVybM2zBaN29Ljd5RddXSbGd2vqf8zz0X8c7hZHBKRATosCwviqIvHyD1NcNAs4qoLCzDQh5nY0SEDpvy1fLXd%2BgOCIEIM
# [+] Host: .addthis.com, Cookie: um, Value: 2JE*3Tv5f5YSh509NINEMI1hcW|2JT!3WLG-GMz-gjkXkKnMbqiS1
# [+] Host: .btrll.com, Cookie: BR_APS, Value: 3U8YWPyikg1cBsguPag
# [+] Host: pix.btrll.com, Cookie: cap_353806, Value: 1
# [+] Host: delivery.swid.switchads.com, Cookie: MMTH, Value: f77c53c5-f364-4500-9c6c-c68c2c05133a
# [+] Host: .go.sonobi.com, Cookie: __uin_mm, Value: f77c53c5-f364-4500-9c6c-c68c2c05133a
# [+] Host: .go.sonobi.com, Cookie: __uis, Value: 25b943fd-bc81-59ba-a98a-23a250762fec
# [+] Host: .nexac.com, Cookie: na_tc, Value: Y
# [+] Host: .contextweb.com, Cookie: V, Value: KG2iiV6yy9ff
# [+] Host: .contextweb.com, Cookie: pb_rtb_ev, Value: 2-530739.f77c53c5-f364-4500-9c6c-c68c2c05133a.0.0.1405490728341
# [+] Host: .kau.li, Cookie: d, Value: %2F%2F%2F%2F%2Ff77c53c5-f364-4500-9c6c-c68c2c05133a%2F%2F%2F%2F%2F%2F%2F%2F
# [+] Host: .kau.li, Cookie: i, Value: qdJtqpNReMDLgdO4RBWfYXZvXi4
# [+] Host: .adtechus.com, Cookie: JEB2, Value: 53C614E5687A1724312014ADF6F98521
# [+] Host: .ib.mookie1.com, Cookie: ibkukiuno, Value: s=1c45f1e1-cf8a-48e6-a91c-9ad8c92e9703&h=&v=0&l=-8587961161566647180&op=0&m=2001107298300991
# [+] Host: .ib.mookie1.com, Cookie: ibkukinet, Value: 2021529165=-8587961161566647180
# [+] Host: .smartadserver.com, Cookie: pid, Value: -1512966561574485995
# [+] Host: .smartadserver.com, Cookie: TestIfCookieP, Value: ok
# [+] Host: .smartadserver.com, Cookie: csync, Value: 25:f77c53c5-f364-4500-9c6c-c68c2c05133a
# [+] Host: .mookie1.com, Cookie: mdata, Value: 1|10965143844578185374|1405487129
# [+] Host: .mookie1.com, Cookie: OAX, Value: q7pcbVPGFikAAcsF
# [+] Host: .acxiom-online.com, Cookie: ACX_COUNT, Value: 5
# [+] Host: .acxiom-online.com, Cookie: ACXID, Value: "V=3&ID=461d8fb0-c39c-4f29-ae0c-fd1dfeafbc95&P29=1405490726787&P7=1405490728107&P26=1405490728676"
# [+] Host: .pubmatic.com, Cookie: KRTBCOOKIE_22, Value: 488-pcv:1|uid:4013138532353362548
# [+] Host: .pubmatic.com, Cookie: KRTBCOOKIE_57, Value: 476-uid:4093121560726061998
# [+] Host: .casalemedia.com, Cookie: CMDD, Value: AAIpkgEAAlADAQ**
# [+] Host: .pubmatic.com, Cookie: KRTBCOOKIE_377, Value: 6810-1752f970-d392-4771-999a-f4009efba3be
# [+] Host: .afy11.net, Cookie: a, Value: nWHU-lIB7ESjSrc2W9Q0Ww
# [+] Host: .afy11.net, Cookie: s, Value: 1,b*53c61a41*2oW6cK8UEP*Uvg2LwJwcXBFLjwQVhQ5bhLyftSr8R-EY7a8hQ==*
# [+] Host: .pubmatic.com, Cookie: PUBRETARGET, Value: 362_1437026727.79_1405578177.78_1500099777.3076_1413267777
# [+] Host: .adnxs.com, Cookie: uuid2, Value: 4093121560726061998
# [+] Host: .adnxs.com, Cookie: sess, Value: 1
# [+] Host: .chango.com, Cookie: _t, Value: a1204302-0cb1-11e4-90ce-00259037fbf0
# [+] Host: .chango.com, Cookie: _vt, Value: 0
# [+] Host: .eyereturn.com, Cookie: er_guid, Value: 0b02f6fa-8873-4984-c97e-b15fd6e2ff2a
# [+] Host: .dsply.com, Cookie: ub_uuid, Value: 5e71f5fc-6e09-4c9b-8f1a-a2da596d4891
# [+] Host: .dsply.com, Cookie: nitpo, Value: 2
# [+] Host: .answers.com, Cookie: dsply_uuid, Value: 5e71f5fc-6e09-4c9b-8f1a-a2da596d4891
# [+] Host: .openx.net, Cookie: i, Value: 9e821af0-0bab-4675-822a-28d2ddfb6e74
# [+] Host: .openx.net, Cookie: pd, Value: 66482baa-af6b-11e1-8f8e-842b2b080a35.1405490724|216c787e-af6b-11e1-8f8e-842b2b080a35.1405490724|d095054c-b000-11e1-8f8e-842b2b080a35.1405490724|a4878f1e-af6b-11e1-8f8e-842b2b080a35.1405491774|d1693dac-af6b-11e1-8f8e-842b2b080a35.1405490724|7182ac20-af6b-11e1-8f8e-842b2b080a35.1405490724|8fefee7a-af6b-11e1-8f8e-842b2b080a35.1405491778
# [+] Host: ad.360yield.com, Cookie: tuuid, Value: 7cb1730b-19ca-4bb5-b3f3-61b47a976f5a
# [+] Host: ad.360yield.com, Cookie: um, Value: !81,AEdl6iCuMqYfyMNuRUub2ss4otQ4fBooEFiIMyjf2RSWTQQKALO.Pf2C.ds#,1405750978!5,KQ3rhlXhquHNiBXwvnAGMm0BWHctzOf4ReoFluoysoDPl37y1xazUbiQ3hDoyge1di8#,1468562728
# [+] Host: ad.360yield.com, Cookie: umeh, Value: !81,0,236942578,-1!5,0,236941528,-1
# [+] Host: .tubemogul.com, Cookie: _tmid, Value: -1189103273798963520
# [+] Host: .tubemogul.com, Cookie: _tmpi, Value: MjAxNDA3MTY_MzpDQUVTRUdudTBVWVNLeF81eDRZNUlON05BTzA6MzA
# [+] Host: .turn.com, Cookie: uid, Value: 4013138532353362548
# [+] Host: .w55c.net, Cookie: wfivefivec, Value: f2bbdb3f-7c9e-443d-b2db-e3e3c040c3a1
# [+] Host: .turn.com, Cookie: rrs, Value: 1006%7C1004%7C1002%7C9%7C21
# [+] Host: .turn.com, Cookie: rds, Value: 16267%7C16267%7C16267%7C16267%7C16267
# [+] Host: .turn.com, Cookie: rv, Value: 1
# [+] Host: .eqads.com, Cookie: EQUser, Value: UID=32a37356-c340-47ad-a814-d0eb83ecd50a
# [+] Host: .casalemedia.com, Cookie: CMST, Value: U8YWKFPGGkMC
# [+] Host: .dotomi.com, Cookie: DotomiUser, Value: 872102399815216414$3$42$$1
# [+] Host: .fastclick.net, Cookie: pluto, Value: 872102399815216414|v1
# [+] Host: .wtp101.com, Cookie: tuuid, Value: e746efb0-d2b1-4c3b-a773-a7e3648ff261
# [+] Host: .connexity.net, Cookie: refresh, Value: NoUpdate
# [+] Host: .connexity.net, Cookie: COu, Value: e974fca3997e08c9-0645e39581b4e6f7-217a31c8dafbec21
# [+] Host: .rfihub.com, Cookie: e, Value: aa
# [+] Host: .rfihub.com, Cookie: rud, Value: H4sIAAAAAAAAAOMSSTY0MLYwMLc0NzQzNzI0MjQwszQX4jPU1TVKtCjU9SxNyvavlOI1NDEwNbEwNDcxA0oDAN469/81AAAA
# [+] Host: .rfihub.com, Cookie: hl, Value: H4sIAAAAAAAAANNSTHR08i8vd0lPt7V19AwJitJNdQSyHB2dgqqMw3OMkm0BBrtiAyMAAAA=
# [+] Host: .rfihub.com, Cookie: eud, Value: H4sIAAAAAAAAAOOSMXR2dA12daoo8/DVTfJ1KUlycvWODErPSCz0iAziNTQxMDWxMDQ3MTOzNN/ECOFbGpqbmxsbGOyC8Q3MjUwsTM1fMaKq/4Wk3tLE2BAAOOQwc20AAAA=
# [+] Host: .casalemedia.com, Cookie: CMID, Value: U8YWKMAoJT4AAEY2lAEAAAEL
# [+] Host: .casalemedia.com, Cookie: CMPS, Value: 273
# [+] Host: .casalemedia.com, Cookie: CMRUM2, Value: 1c53cf54c20b02f6fa-8873-4984-c97e-b15fd6e2ff2a&2753cf54c11752f970-d392-4771-999a-f4009efba3be&cc53c76bc1&2853cf54c332a37356-c340-47ad-a814-d0eb83ecd50a&0353cf50a8f77c53c5-f364-4500-9c6c-c68c2c05133a&3953cf54c31038079716721210697&d053c76bc1&0253c76bc10&3053c76bc1&2f53cf54c2f2bbdb3f-7c9e-443d-b2db-e3e3c040c3a1&1453cf54c233b88a46-18c0-457c-9d13-1ccca6290972&2a53c76bc20&0453cf54c24013138532353362548&2e53cf54c24093121560726061998&2d53cf54c3CAESEIpC3G_WYB94bXDrRbFid-E&3e53c76bc1&3753cf54c2e974fca3997e08c9-0645e39581b4e6f7
# [+] Host: .c.appier.net, Cookie: _auid, Value: mPQvZdhVSkyXpeMuOTKx6A
# [+] Host: .crwdcntrl.net, Cookie: _cc_aud, Value: "ABR4nGNgYGAIPiblzgADWgwMJ0XArFeOYOrMTDDFNQNMCf0AU3O%2Fgamd88DUfh8wteQQmLquAab0NMGUwCwwdfIRmLpzEUyVO4GpUzfAlOcDiBJRMDUlE0xNz4dQeWCqdAqYcp0ApvwhGvzZwNQeCO%2BVBZh68x9C%2FQNTa7eBKd0FEN4eMHW7Hky1LYRQELm2%2BWDqwj0wJZoApppYwdQiEzDlVwqmrhgDCQBFijB%2F"
# [+] Host: .crwdcntrl.net, Cookie: _cc_cc, Value: "ACN4nGNQSEtMSk1MS0xMNjJOszQwSTFJTTFJsjRPNkgyszRKsTBkAILgY1Lu%2F%2F%2F%2FvseADPgfn1vKyCDwkIHhPyMjAyMDA%2BPr7ko0gbyjqAIvXxegqWhhRRPIXoQq8OZRK6rAi6YAVIGP9nPRrZ2BKvDVOhfNHZKyqALvpOehC6AZylh7g5FBqPH%2FO5gAAz93wi5muBDDWQgN08OdsBO35GedWiDnAYTTYTMTqELy%2F3sQ58a6xbi1KXO9wS15Y2kIPskg3JKcz1%2FjlmwXvIBH5%2BO7%2BHQexi1ZsOg8PslzuCX5qlxxSwIA3XTc9A%3D%3D"
# [+] Host: .crwdcntrl.net, Cookie: _cc_id, Value: fabeafaac23f904d4ed4b97c0b692d81
# [+] Host: .crwdcntrl.net, Cookie: _cc_domain, Value: .cc.answers.com
# [+] Host: .answers.com, Cookie: appinitjs_193466177382032, Value: unknown
# [+] Host: .answers.com, Cookie: __utma, Value: 140385260.1465079941.1405491776.1405491776.1405491776.1
# [+] Host: .answers.com, Cookie: __utmb, Value: 140385260.4.9.1405491791759
# ...
# [+] Host: .support.mozilla.org, Cookie: __utmz, Value: 62528430.1417414796.1.1.utmcsr=inproduct|utmccn=(not%20set)|utmcmd=(not%20set)
# [+] Host: .mozilla.org, Cookie: __utmt, Value: 1
# [+] Host: .mozilla.org, Cookie: __utma, Value: 150903082.2127863903.1405411462.1405411462.1417414836.2
# [+] Host: .mozilla.org, Cookie: __utmb, Value: 150903082.2.9.1417414839488
# [+] Host: .mozilla.org, Cookie: __utmz, Value: 150903082.1405411462.1.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none)
# [+] Host: download.mozilla.org, Cookie: dmo, Value: 120.126.22.80.1423625202108065
# [+] Host: .google.com, Cookie: PREF, Value: ID=1111111111111111:TM=1405298413:LM=1421104915:S=55bk8iXnNx3V3mKm
# [+] Host: accounts.youtube.com, Cookie: CheckConnectionTempCookie323, Value: 281268
# [+] Host: .microbe.net, Cookie: __utmt, Value: 1
# [+] Host: .microbe.net, Cookie: __utma, Value: 261246225.2027444920.1405497601.1405646605.1444104659.4
# [+] Host: .microbe.net, Cookie: __utmb, Value: 261246225.1.10.1444104659
# [+] Host: .microbe.net, Cookie: __utmz, Value: 261246225.1444104659.4.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none)
# [+] Host: .cgu.edu.tw, Cookie: _ga, Value: GA1.3.1172715361.1404974627
# [+] Host: .cgu.edu.tw, Cookie: _gat, Value: 1
# [+] Host: .apple.com, Cookie: s_vi, Value: [CS]v1|295368FF85011D5A-6000010C80027898[CE]
# [+] Host: .apple.com, Cookie: s_fid, Value: 1F3D3A7E1E67B2B0-07630199E52C7C75
# [+] Host: .apple.com, Cookie: s_pathLength, Value: developer%3D1%2C
# [+] Host: .apple.com, Cookie: s_invisit_n2_us, Value: 19
# [+] Host: .apple.com, Cookie: s_vnum_n2_us, Value: 19%7C2%2C4%7C1
# [+] Host: .apple.com, Cookie: s_ppv, Value: apple%2520developer%2520-%2520%2528english%2529%2C25%2C25%2C640%2C
# [+] Host: tw.yahoo.com, Cookie: ywandp, Value: 10001697310762%3A1310787700%3B10001808994279%3A918863479
# [+] Host: .tw.yahoo.com, Cookie: CRZY, Value: %7B%22323644449_20151006%22%3A%7B%22expires%22%3A1444277469879%2C%22data%22%3A%7B%22nv%22%3A1%2C%22bn%22%3A0%2C%22collapsed%22%3A0%7D%7D%7D
# [+] Host: tw.yahoo.com, Cookie: fpc, Value: 10001808994279%3AZUK7-Uc9%7C%7C
# [+] Host: , Cookie: __utma, Value: 1.1632499250.1405560535.1405560535.1449964928.2
# [+] Host: , Cookie: __utmb, Value: 1.0.10.1449964928
# [+] Host: , Cookie: __utmz, Value: 1.1449964928.2.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none)
# [+] Host: .mozilla.org, Cookie: optimizelySegments, Value: %7B%22245617832%22%3A%22none%22%2C%22245875585%22%3A%22direct%22%2C%22245677587%22%3A%22ff%22%2C%22246048108%22%3A%22false%22%2C%222000810488%22%3A%22false%22%2C%222017550344%22%3A%22ff%22%2C%221994990450%22%3A%22none%22%2C%222011280991%22%3A%22direct%22%7D
# [+] Host: .mozilla.org, Cookie: optimizelyBuckets, Value: %7B%7D
# [+] Host: .blocklist.addons.mozilla.org, Cookie: __utmt, Value: 1
# [+] Host: .blocklist.addons.mozilla.org, Cookie: __utma, Value: 264441052.2127863903.1405411462.1453855270.1453855270.1
# [+] Host: .blocklist.addons.mozilla.org, Cookie: __utmb, Value: 264441052.1.10.1453855270
# [+] Host: .blocklist.addons.mozilla.org, Cookie: __utmz, Value: 264441052.1453855270.1.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none)
# [+] Host: .mozilla.org, Cookie: optimizelyPendingLogEvents, Value: %5B%5D
# [+] Host: login.persona.org, Cookie: browserid_state, Value: k0bVWeeKB28aG3IxBkpJLQ.fbrGPK8Y9ldJFpDyQ46kulWjEwLCZK355XQhYnD3vkFEb6TRqc6egT4gr0BaCmK2HwkBk7mhcZGxhjAGs2z5mg.1453855315909.2419200000.c9zbExIqgHpQxpYdkGo4ajsozF7SeUSX71Gn3H-FJ-8
# [+] Host: .addons-dev.allizom.org, Cookie: __utmt, Value: 1
# [+] Host: .addons-dev.allizom.org, Cookie: __utma, Value: 128045276.1727245963.1453855328.1453855328.1453855328.1
# [+] Host: .addons-dev.allizom.org, Cookie: __utmb, Value: 128045276.1.10.1453855328
# [+] Host: .addons-dev.allizom.org, Cookie: __utmz, Value: 128045276.1453855328.1.1.utmcsr=bugzilla.mozilla.org|utmccn=(referral)|utmcmd=referral|utmcct=/show_bug.cgi
# [+] Host: .mozilla.org, Cookie: _gat_UA-36116321-1, Value: 1
# [+] Host: .mozilla.org, Cookie: _ga, Value: GA1.2.2127863903.1405411462
# [+] Host: .mozilla.org, Cookie: _gali, Value: plugin-vulnerable
# [+] Host: .serving-sys.com, Cookie: OT2, Value: 0000Q.2dhI
# [+] Host: .serving-sys.com, Cookie: u2, Value: 754370b4-0b49-4f0c-a38f-e8ebe5fe7a9d47H01g
# [+] Host: .liveperson.net, Cookie: LivePersonID, Value: LP i=1131902364615550,d=1458088828
# [+] Host: .liveperson.net, Cookie: LivePersonID, Value: -1131902364615550-1458088828:-1:-1:-1:-1
# [+] Host: .ibm.com, Cookie: mp_mixpanel__c, Value: 2
# [+] Host: watson.analytics.ibmcloud.com, Cookie: CookieChecker, Value: set
# [+] Host: .ibmcloud.com, Cookie: CoreID6, Value: 36899351725114580888299&ci=50200000|Watson Analytics
# [+] Host: .adsrvr.org, Cookie: TDID, Value: 94f0215d-b835-4079-89a6-f34b882c98b1
# [+] Host: .adsrvr.org, Cookie: TDCPM, Value: CAESFgoHdGVhbGl1bRILCOy+pPezz+YzEAUYASABKAIyCwjstqekys/mMxAFOAFaB3RlYWxpdW1gAg==
# [+] Host: .tealiumiq.com, Cookie: TVT, Value: Wed+Mar+16+00%3A40%3A25+2016~94f0215d-b835-4079-89a6-f34b882c98b1~~~~~~~~~
# [+] Host: .ibmcloud.com, Cookie: CoreM_State, Value: 96~-1~-1~-1~-1~3~3~5~3~3~7~7~|~~|~~|~~|~||||||~|~~|~~|~~|~~|~~|~~|~~|~
# [+] Host: .ibmcloud.com, Cookie: CoreM_State_Content, Value: 6~|~~|~|
# [+] Host: community.watsonanalytics.com, Cookie: NSC_XbutpoXFC, Value: ffffffff0965851545525d5f4f58455e445a4a423660
# [+] Host: .watsonanalytics.com, Cookie: _ga, Value: GA1.2.600227388.1458088863
# [+] Host: .watsonanalytics.com, Cookie: _gat, Value: 1
# [+] Host: .watsonanalytics.com, Cookie: mp_99eae710988eb1dc7827febeaa5ccf35_mixpanel, Value: %7B%22distinct_id%22%3A%20%221537cde672b7d-08cf29eba00266-48546e-13c680-1537cde672c63e%22%2C%22%24initial_referrer%22%3A%20%22https%3A%2F%2Fwatson.analytics.ibmcloud.com%2Flogin%3Fwatsonanalytics%3Dtrue%26cm_mmc%3DWAMicrosite-_-Organic-_-Organic-_-Organic%22%2C%22%24initial_referring_domain%22%3A%20%22watson.analytics.ibmcloud.com%22%7D
# [+] Host: .linkedin.com, Cookie: lidc, Value: "b=LGST00:g=44:u=1:i=1458088863:t=1458175263:s=AQHGoIbrO5_XrLpIaROxnfL-Zn8Q6NsZ"
# [+] Host: .twitter.com, Cookie: pid, Value: "v3:1458088864541423112493039"
# [+] Host: .watsonanalytics.com, Cookie: mp_mixpanel__c, Value: 2
# [+] Host: .ibmcloud.com, Cookie: utag_main, Value: v_id:01537cdde32200179cd6a2812c1003052007100f0093c$_sn:1$_ss:0$_pn:2%3Bexp-session$_st:1458090678039$ses_id:1458088829730%3Bexp-session$dc_visit:1$dc_event:3%3Bexp-session$ttd_uuid:94f0215d-b835-4079-89a6-f34b882c98b1%3Bexp-session$dc_region:us-west-1%3Bexp-session
# [+] Host: .ibmcloud.com, Cookie: mmcore.tst, Value: 0.274
# [+] Host: .ibmcloud.com, Cookie: mmapi.store.p.0, Value: %7B%22mmparams.d%22%3A%7B%7D%2C%22mmparams.p%22%3A%7B%22mmid%22%3A%221489624878586%7C%5C%22-1524879744%7CAgAAAAokOVJRIg0AAA%3D%3D%5C%22%22%2C%22pd%22%3A%221489624878588%7C%5C%22737204654%7CAgAAAAoBQiQ5UlEiDVwhtooBAEWPPLAzTdNIDwAAANeDPpMzTdNIAAAAAP%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FAAt3d3cuaWJtLmNvbQIiDQEAAAAAAAAAAAAA%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FAAAAAAABRQ%3D%3D%5C%22%22%2C%22srv%22%3A%221489624878589%7C%5C%22lvsvwcgus02%5C%22%22%7D%7D
# [+] Host: .tealiumiq.com, Cookie: TAPID, Value: ibm/main>01537cddd03b0000e3b00389c52003052002e00f0093c|
# [+] Host: .getfirebug.com, Cookie: __utma, Value: 106016604.1432991826.1389315053.1453855256.1461217348.11
# [+] Host: .getfirebug.com, Cookie: __utmz, Value: 106016604.1444104181.9.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none)
# [+] Host: .getfirebug.com, Cookie: __utmt, Value: 1
# [+] Host: .getfirebug.com, Cookie: __utmb, Value: 106016604.1.10.1461217348
# [+] Host: .google.com, Cookie: SNID, Value: 78=gw4MfykbZINjXx8U94SSYYyjWyCLgOdMNb5uY-mS=YV-ZvsG5J9z29Tvy
# [+] Host: .groups.google.com, Cookie: __utma, Value: 118165087.1603563283.1405655719.1405658793.1461570991.3
# [+] Host: .groups.google.com, Cookie: __utmz, Value: 118165087.1461570991.3.1.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided)
# [+] Host: .groups.google.com, Cookie: __utmt_*groups_ga*, Value: 1
# [+] Host: .groups.google.com, Cookie: __utmb, Value: 118165087.1.10.1461570991
# [+] Host: www.google.com.tw, Cookie: DV, Value: Indsc_INXFAddPPDgiI1UyUhDOiYqAI
# [+] Host: .google.com.tw, Cookie: OGPC, Value: 5061821-4:
# [+] Host: .sagemath.org, Cookie: __utma, Value: 138969649.1451581924.1461571555.1461571555.1461571555.1
# [+] Host: .sagemath.org, Cookie: __utmz, Value: 138969649.1461571555.1.1.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided)
# [+] Host: .sagemath.org, Cookie: __utmt, Value: 1
# [+] Host: .sagemath.org, Cookie: __utmb, Value: 138969649.1.10.1461571555
# [+] Host: www.sagemath.org, Cookie: HstCfa1579950, Value: 1461571555730
# [+] Host: www.sagemath.org, Cookie: HstCla1579950, Value: 1461571555730
# [+] Host: www.sagemath.org, Cookie: HstCmu1579950, Value: 1461571555730
# [+] Host: www.sagemath.org, Cookie: HstPn1579950, Value: 1
# [+] Host: www.sagemath.org, Cookie: HstPt1579950, Value: 1
# [+] Host: www.sagemath.org, Cookie: HstCnv1579950, Value: 1
# [+] Host: www.sagemath.org, Cookie: HstCns1579950, Value: 1
# [+] Host: www.sagemath.org, Cookie: c_ref_1579950, Value: https%3A%2F%2Fwww.google.com.tw
# [+] Host: .histats.com, Cookie: CountUid, Value: ba19f400-63ys-4eae-b58c-e5dfae397b3a
# [+] Host: .sagemath.com, Cookie: __cfduid, Value: db82d7c44c451954b3c4044f9f9d634541461571563
# [+] Host: .sagemath.com, Cookie: _ga, Value: GA1.2.1280285890.1461571567
# [+] Host: .sagemath.com, Cookie: _gat, Value: 1
# [+] Host: cloud.sagemath.com, Cookie: remember_me, Value: sha512$279c7c78231ba7e2ab6538d73b1596dd$1000$2e265bf4-b9a4-4dfd-aab5-0ff665652a1a
# [+] Host: cloud.sagemath.com, Cookie: cf_use_ob, Value: 0
# [+] Host: .codecanyon.net, Cookie: referring_user, Value: -1
# [+] Host: .codecanyon.net, Cookie: _ga, Value: GA1.2.1632751513.1462325747
# [+] Host: .doubleclick.net, Cookie: IDE, Value: AHWqTUnTnthCVIqLMhrUr2oHR7rbMlDi5qU2FtWqsU0xwtk5WPhtH625Hg
# [+] Host: .codecanyon.net, Cookie: _gat_m, Value: 1
# [+] Host: .codecanyon.net, Cookie: _gat_author_analytics, Value: 1

# %% [markdown]
# An investigator may also wish to enumerate the browser history. Firefox stores this data in a database named places.sqlite. Here, the moz_places table gives us valuable columns that include information about when (date) and where (address) a user visited a site. While our script for printHistory() only takes into account the moz_places table, the ForensicWiki Web site recommends using data from both the moz_places table and the moz_historyvisits table as well to get a live browser history (Forensics Wiki, 2011).

# %%
def printHistory(placesDB):
    try:
        conn = sqlite3.connect(placesDB)
        c = conn.cursor()
        c.execute("select url, datetime(visit_date/1000000, \
          'unixepoch') from moz_places, moz_historyvisits \
          where visit_count > 0 and moz_places.id==\
          moz_historyvisits.place_id;")

        print('\n[*] -- Found History --')
        for row in c:
            url = str(row[0])
            date = str(row[1])
            print('[+] ' + date + ' - Visited: ' + url)
    except Exception as e:
        if 'encrypted' in str(e):
            print('\n[*] Error reading your places database.')
            print('[*] Upgrade your Python-Sqlite3 Library')
            exit(0)

# %%
printHistory('history.sqlite')

# %%
import re
def printGoogle(placesDB):
    conn = sqlite3.connect(placesDB)
    c = conn.cursor()
    c.execute("select url, datetime(visit_date/1000000, \
      'unixepoch') from moz_places, moz_historyvisits \
      where visit_count > 0 and moz_places.id==\
      moz_historyvisits.place_id;")

    print('\n[*] -- Found Google --')
    for row in c:
        url = str(row[0])
        date = str(row[1])
        if 'google' in url.lower():
            r = re.findall(r'q=.*\&', url)
            if r:
                search=r[0].split('&')[0]
                search=search.replace('q=', '').replace('+', ' ')
                print('[+] '+date+' - Searched For: ' + search)

# %% [markdown]
# Let’s use the last example and our knowledge of regular expressions to expand the previous function. While browser history is in nitely valuable, it would be useful to look deeper into some of the speci c URLs visited. Google search queries contain the search terms right inside of the URL, for example. In the wireless section, we will expand on this in great depth. However, right now, let’s just extract the search terms right out of the URL. If we spot a URL in our history that contains Google, we will search it for the characters `q=` followed by an `&`. This speci c sequence of characters indicates a Google search. If we do  nd this term, we will clean up the output by replacing some of the characters used in URLs to pad whitespace with actual whitespace. Finally, we will print out the corrected output to the screen. Now we have a function that can search the places.sqlite  le for and print out Google search queries.

# [+] 2016-04-25 08:05:14 - Searched For: sage jmol not working
# [+] 2016-04-25 08:05:15 - Searched For: sage jmol not working
# [+] 2016-04-25 08:05:52 - Searched For: sagemath
# [+] 2016-04-25 08:05:52 - Searched For: sagemath
# [+] 2014-07-03 23:25:04 - Searched For: jdk
# [+] 2014-07-03 23:30:21 - Searched For: jdk
# [+] 2014-07-16 06:49:41 - Searched For: %E9%95%B7%E5%BA%9A %E5%A7%9A%E5%B0%8F%E5%AE%87
# [+] 2014-07-16 06:51:46 - Searched For: %E9%95%B7%E5%BA%9A %E5%A7%9A%E5%B0%8F%E5%AE%87
# [+] 2014-07-17 01:31:03 - Searched For: inevitable
# [+] 2014-07-17 02:21:20 - Searched For: inevitable
# [+] 2014-07-17 07:01:47 - Searched For: %E5%8C%97%E9%86%AB%E9%86%AB%E5%AD%B8%E7%87%9F2014
# [+] 2014-07-17 07:51:48 - Searched For: %E5%8C%97%E9%86%AB%E9%86%AB%E5%AD%B8%E7%87%9F2014
# [+] 2014-11-04 06:32:12 - Searched For: jquery mobil fail after a link
# [+] 2014-11-04 06:45:48 - Searched For: jquery mobil fail after a link

# %% [markdown]
# INVESTIGATING ITUNES MOBILE BACKUPS
# ---
# In April 2011, security researcher and former Apple employee Pete Warden disclosed a privacy issue with the popular Apple iPhone/Ipad iOS operating system (Warden, 2011). After a significant investigation, Mr. Warden revealed proof that the Apple iOS operating system actually tracked and recorded the GPS coordinates of the device and stored them in a database on the phone called `consolidated.db` (Warden, 2011). Inside this database, a table named Cell-Location contained the GPS points the phone had collected. The device determined the location information by triangulating off the nearest cell-phone towers in order to provide the best service for the device user. However, as Mr. Warden suggested, this same data could be used maliciously to track the entire movements an iPhone/iPad user. Furthermore, the process used to backup and store a copy of the mobile device to a computer also recorded this information. While the location-recording information has been removed from the Apple iOS operating system functionality, the process Mr. Warden used to discover the data remains. In this section, we will repeat this process to extract information from iOS mobile device backups. Specifically, we will extract all the text messages out of an iOS backup using a Python script.
#
# ```
# ~/Library/Application Support/MobileSync/Backup
# ```

# %%
import os

def isMessageTable(iphoneDB):
    try:
        conn = sqlite3.connect(iphoneDB)
        c = conn.cursor()
        c.execute('SELECT tbl_name FROM sqlite_master \
          WHERE type==\"table\";')
        for row in c:
            if 'message' in str(row):
                return True
    except:
        return False


def printMessage(msgDB):
    try:
        conn = sqlite3.connect(msgDB)
        c = conn.cursor()
        c.execute('select datetime(date,\'unixepoch\'),\
          address, text from message WHERE address>0;')
        for row in c:
            date = str(row[0])
            addr = str(row[1])
            text = row[2]
            print('\n[+] Date: '+date+', Addr: '+addr \
                + ' Message: ' + text)
    except:
        pass

def iphoneMessage(pathName):
    dirList = os.listdir(pathName)
    for fileName in dirList:
        iphoneDB = os.path.join(pathName, fileName)
        if isMessageTable(iphoneDB):
            try:
                print('\n[*] --- Found Messages ---')
                printMessage(iphoneDB)
            except:
                pass

# %% [markdown]
# Try
# ```
# iphoneMessage('where-the backup-dircetory')
# ```
